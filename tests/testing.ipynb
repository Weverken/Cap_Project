# %%
import sys
from pathlib import Path

# Add Cap_Project to Python's import path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from src.ai_client import AIClient

print("✅ AIClient imported successfully!")
# Out:
# ✅ AIClient imported successfully!

# %%
ai = AIClient()

response = ai.chat(
    "What is artificial intelligence in one sentence?"
)

print(response)
# Out:
# Artificial intelligence is the branch of computer science dedicated to creating systems capable of performing tasks that typically require human intelligence, such as learning, reasoning, problem-solving, and decision-making.
